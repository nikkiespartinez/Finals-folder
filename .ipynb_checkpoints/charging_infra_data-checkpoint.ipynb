# %%
import pandas as pd

# %%
df = pd.read_excel('10962-ev-registration-counts-by-state_6-11-21.xlsx')
df
# Out:
#     Unnamed: 0                               Unnamed: 1          Unnamed: 2  \
# 0          NaN  Electric Vehicle Registrations by State                 NaN
# 1          NaN                                    State  Registration Count
# 2          NaN                                  Alabama                2890
# 3          NaN                                   Alaska                 940
# 4          NaN                                  Arizona               28770
# 5          NaN                                 Arkansas                1330
# 6          NaN                               California              425300
# 7          NaN                                 Colorado               24670
# 8          NaN                              Connecticut                9040
# 9          NaN                                 Delaware                1950
# 10         NaN                     District of Columbia                2360
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 41 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   0 non-null      float64
#  1   Unnamed: 1   54 non-null     object
#  2   Unnamed: 2   53 non-null     object
#  3   Unnamed: 3   0 non-null      float64
#  4   Unnamed: 4   8 non-null      object
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
#  8   Unnamed: 8   0 non-null      float64
#  9   Unnamed: 9   0 non-null      float64
#  10  Unnamed: 10  0 non-null      float64
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  0 non-null      float64
#  16  Unnamed: 16  0 non-null      float64
#  17  Unnamed: 17  0 non-null      float64
# ...

# %%
df.drop([0])
# Out:
#     Unnamed: 0            Unnamed: 1          Unnamed: 2  Unnamed: 3  \
# 1          NaN                 State  Registration Count         NaN
# 2          NaN               Alabama                2890         NaN
# 3          NaN                Alaska                 940         NaN
# 4          NaN               Arizona               28770         NaN
# 5          NaN              Arkansas                1330         NaN
# 6          NaN            California              425300         NaN
# 7          NaN              Colorado               24670         NaN
# 8          NaN           Connecticut                9040         NaN
# 9          NaN              Delaware                1950         NaN
# 10         NaN  District of Columbia                2360         NaN
# 11         NaN               Florida               58160         NaN
# 12         NaN               Georgia               23530         NaN
# 13         NaN                Hawaii               10670         NaN
# ...

# %%
n = df[['Unnamed: 1','Unnamed: 2']]
n
# Out:
#                                  Unnamed: 1          Unnamed: 2
# 0   Electric Vehicle Registrations by State                 NaN
# 1                                     State  Registration Count
# 2                                   Alabama                2890
# 3                                    Alaska                 940
# 4                                   Arizona               28770
# 5                                  Arkansas                1330
# 6                                California              425300
# 7                                  Colorado               24670
# 8                               Connecticut                9040
# 9                                  Delaware                1950
# 10                     District of Columbia                2360
# 11                                  Florida               58160
# 12                                  Georgia               23530
# 13                                   Hawaii               10670
# ...

# %%
n.drop(labels=['Unnamed: 1','Unnamed: 2'], axis=0)
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6af107d2b107> in <module>
# ----> 1 n.drop(labels, axis=0)
#       2 n
#
# NameError: name 'labels' is not defined
